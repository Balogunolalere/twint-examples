# %% [markdown]
# <a href="https://colab.research.google.com/github/Balogunolalere/twint-examples/blob/main/twint_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twint==2.1.21
# !pip install -qq nest_asyncio

# %%
import twint
twint.__version__
# Out:
# '2.1.21'

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# !twint -u asakuneri
# Out:
# 1471818402973028358 2021-12-17 12:23:46 +0000 <asakuneri> @dinocares 😅
# 1471757549166866432 2021-12-17 08:21:58 +0000 <asakuneri> In the Christmas card to my colleagues I wrote; 'let's make more magic in 2022 and less accident' 😩 Yes with the smiley.
# 1471756789083480067 2021-12-17 08:18:57 +0000 <asakuneri> How can one person have plenty sense like this?! This man is entering my eyes.
# 1471561472140525569 2021-12-16 19:22:49 +0000 <asakuneri> @timiokoya I cover my brother and friends +/- Dr T with the blood of Jesus
# 1471559026408411140 2021-12-16 19:13:06 +0000 <asakuneri> @timiokoya Dr T my former Z...., Yoruba men are what?
# 1471557440336535564 2021-12-16 19:06:48 +0000 <asakuneri> @timiokoya Do you know him ni
# 1471538161675386885 2021-12-16 17:50:12 +0000 <asakuneri> Dr T used to be my amebo partner....
# ...

# %%
# !twint -u bandersnatchx64 -s lol
# Out:
# 1467097411080310788 2021-12-04 11:44:14 +0000 <BanderSnatchx64> @TheIgalaPrince @badniggafela Lol...she dey take online tutorial to add to profile😂🤲🏾
# 1461021737034915843 2021-11-17 17:21:41 +0000 <BanderSnatchx64> @danielejiro9 Lol...person talk "Girl please"😂😂😂
# 1460978566351540232 2021-11-17 14:30:08 +0000 <BanderSnatchx64> @PostPCEra @darkgaro Lol...twitter who?
# 1460978422751141888 2021-11-17 14:29:34 +0000 <BanderSnatchx64> @darkgaro Lol...Netflix who?
# 1457857173493530626 2021-11-08 23:46:50 +0000 <BanderSnatchx64> @Lissa__babygirl Lol ...coaster biscuits, wanted it to be hard😂
# 1457657775530684416 2021-11-08 10:34:30 +0000 <BanderSnatchx64> @ramos_244 @tysorosey Lol Very soon he will be meme-fied and all over Twitter
# 1457128450796527616 2021-11-06 23:31:09 +0000 <BanderSnatchx64> @jukebapes @chaneltyers Lol
# 1455858127035830282 2021-11-03 11:23:20 +0000 <BanderSnatchx64> @seanklean_ Lol
# 1442071164701057025 2021-09-26 10:18:52 +0000 <BanderSnatchx64> @fadererah_ LOL
# ...

# %%
# !twint -u bandersnatchx64 --followers --user-full
# Out:
# CRITICAL:root:twint.feed:Follow:IndexError

# %%
c = twint.Config()

c.Search = "Black Axe"
c.Limit = 10000
c.Lang = 'en'

twint.run.Search(c)
# Out:
# 1471834117033582606 2021-12-17 13:26:13 +0000 <axetogrindcast> Black Flag Live 84 is great and it’s not even the best live black flag record
# 1471833208744464386 2021-12-17 13:22:36 +0000 <politicofareeda> This Black Axe documentary is heavy.
# 1471831834208059394 2021-12-17 13:17:09 +0000 <otomololu> Black Axe: Nigeria’s Mafia Cult - BBC Africa Eye documentary  https://t.co/tOXVh18KSP via @YouTube
# 1471830143375130627 2021-12-17 13:10:26 +0000 <lpdetorres> Black Axe, la secta ultraviolenta más peligrosa y de mayor alcance del mundo  https://t.co/U3Yzhf2YDj a través de @_Contrainfo
# 1471827020757835777 2021-12-17 12:58:01 +0000 <BlackSpyr0> @TempoAxe I'm rooting for you Axe, good luck!!! ✨
# 1471826948359741440 2021-12-17 12:57:44 +0000 <BCNRlyrics> I'll bury the axe here, between the window and the kingdom of men
# ...

# %%
c = twint.Config()
c.Store_object = True
c.Pandas =True
c.Search = "pussy"
c.Limit = 1000
c.Lang = 'en'

# %%
twint.run.Search(c)
# Out:
# 1471839088735145987 2021-12-17 13:45:58 +0000 <choerrylips_> MY PUSSY IS THROBBIMH OH MY GOF
# 1471839081848098818 2021-12-17 13:45:57 +0000 <malefemalelooka> Older horny sugarmommy (Nina Harley) makes a college girl lick her wet pussy !! #lesbian #lesbians #porn #sex #lesbianporn #lesbiansex  #sugarmommy #ninahartley  https://t.co/XEhWsValYW
# 1471839081407688705 2021-12-17 13:45:57 +0000 <w0lvesno1> Wel he has gone not only is @BorisJohnson @10DowningStreet  a Quiz Master but also a Pizza player  it it's not just him is it there are plenty of @Conservatives who have Broken their OWN RULES which is a CRIME now we need the @metpoliceuk to sort this out instead of being pussies
# 1471839068518498305 2021-12-17 13:45:54 +0000 <rociiovarela> Gracias personita de los baños de Látex que me apodó como "pussy exclusive" después de decirme lo guapa que era y tratarme como una diosa. ✨✨
# ...

# %%
twint.storage.panda.Tweets_df
# Out:
#                        id      conversation_id  ...  trans_src trans_dest
# 0     1471839088735145987  1471839088735145987  ...
# 1     1471839081848098818  1471839081848098818  ...
# 2     1471839081407688705  1471839081407688705  ...
# 3     1471839068518498305  1471839068518498305  ...
# 4     1471839060771540994  1471600584746668035  ...
# ...                   ...                  ...  ...        ...        ...
# 1012  1471829950147842056  1471743899429478401  ...
# 1013  1471829947434033158  1470395448494108672  ...
# 1014  1471829945827659782  1468625411345166351  ...
# 1015  1471829930958852099  1471265597891645442  ...
# 1016  1471829909354000393  1471815558148542470  ...
#
# [1017 rows x 38 columns]
# ...

# %%
twint.storage.panda.Tweets_df.dtypes
# Out:
# id                  object
# conversation_id     object
# created_at         float64
# date                object
# timezone            object
# place               object
# tweet               object
# language            object
# hashtags            object
# cashtags            object
# user_id              int64
# user_id_str         object
# username            object
# name                object
# day                  int64
# hour                object
# link                object
# urls                object
# photos              object
# video                int64
# thumbnail           object
# retweet               bool
# nlikes               int64
# nreplies             int64
# nretweets            int64
# quote_url           object
# search              object
# near                object
# geo                 object
# source              object
# user_rt_id          object
# user_rt             object
# retweet_id          object
# reply_to            object
# ...

# %%
twint.storage.panda.Tweets_df.index
# Out:
# RangeIndex(start=0, stop=1017, step=1)

# %%
twint.storage.panda.Tweets_df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
twint.storage.panda.Tweets_df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                        id      conversation_id  ...  trans_src trans_dest
# 0     1471839088735145987  1471839088735145987  ...
# 1     1471839081848098818  1471839081848098818  ...
# 2     1471839081407688705  1471839081407688705  ...
# 3     1471839068518498305  1471839068518498305  ...
# 4     1471839060771540994  1471600584746668035  ...
# ...                   ...                  ...  ...        ...        ...
# 1012  1471829950147842056  1471743899429478401  ...
# 1013  1471829947434033158  1470395448494108672  ...
# 1014  1471829945827659782  1468625411345166351  ...
# 1015  1471829930958852099  1471265597891645442  ...
# 1016  1471829909354000393  1471815558148542470  ...
#
# [1017 rows x 38 columns]>

# %%
twint.storage.panda.Tweets_df.describe()
# Out:
#          created_at       user_id  ...     nreplies    nretweets
# count  1.017000e+03  1.017000e+03  ...  1017.000000  1017.000000
# mean   1.639748e+12  1.015970e+18  ...     0.283186     0.209440
# std    6.390072e+05  5.462619e+17  ...     0.991322     1.087867
# min    1.639747e+12  7.680112e+06  ...     0.000000     0.000000
# 25%    1.639747e+12  8.580920e+17  ...     0.000000     0.000000
# 50%    1.639748e+12  1.281982e+18  ...     0.000000     0.000000
# 75%    1.639748e+12  1.410865e+18  ...     0.000000     0.000000
# max    1.639749e+12  1.471829e+18  ...    18.000000    16.000000
#
# [8 rows x 7 columns]
